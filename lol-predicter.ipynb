# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_data.csv", index_col=0)

# %%
df
# Out:
#                       gameid league  year  playoffs                 date  \
# 0             NA1_3961909585    UPL  2021         0  2021-07-03 00:09:38
# 1             NA1_3961909585    UPL  2021         0  2021-07-03 00:09:38
# 2             NA1_3961869577    UPL  2021         0  2021-07-03 00:09:54
# 3             NA1_3961869577    UPL  2021         0  2021-07-03 00:09:54
# 4             NA1_3964329988    UPL  2021         0  2021-07-03 00:18:04
# ...                      ...    ...   ...       ...                  ...
# 60168  ESPORTSTMNT01_3436660   NEXO  2024         0  2023-11-20 19:05:47
# 60169  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
# 60170  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
# 60171  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
# 60172  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
#
#        patch  side                     teamname  gamelength  kills  ...  \
# 0      11.13     1                   ConViction     1934324     17  ...
# 1      11.13     0                  Mercenaries     1934324      6  ...
# 2      11.13     1     Striking Vipers Maestros     1934690     17  ...
# 3      11.13     0             RockTribeEsports     1934690     33  ...
# 4      11.13     1  Purdue University Northwest     1782343     13  ...
# ...      ...   ...                          ...         ...    ...  ...
# 60168  13.22     1                 Kawaii Kiwis        1940     21  ...
# 60169  13.22     0               Erfolg Esports        2464     20  ...
# 60170  13.22     1                 Kawaii Kiwis        2464     25  ...
# 60171  13.22     1                 Kawaii Kiwis        2464     25  ...
# 60172  13.22     0               Erfolg Esports        2464     20  ...
#
#        xpdiffat15  csdiffat15  killsat15  assistsat15  deathsat15  \
# 0         -1474.0       -81.0        4.0          3.0         2.0
# 1          1474.0        81.0        2.0          3.0         4.0
# 2         -3489.0       -25.0        4.0          5.0        10.0
# 3          3489.0        25.0       10.0         17.0         4.0
# 4         -1246.0       -34.0        5.0          4.0        12.0
# ...           ...         ...        ...          ...         ...
# 60168       545.0        54.0        3.0          4.0         5.0
# 60169      1568.0        34.0        2.0          0.0         4.0
# 60170     -1568.0       -34.0        4.0          7.0         2.0
# 60171     -1568.0       -34.0        4.0          7.0         2.0
# 60172      1568.0        34.0        2.0          0.0         4.0
#
#        opp_killsat15  opp_assistsat15  opp_deathsat15  result  target
# 0                2.0              3.0             4.0       1       1
# 1                4.0              3.0             2.0       0       0
# 2               10.0             17.0             4.0       0       1
# 3                4.0              5.0            10.0       1       0
# 4               12.0             17.0             5.0       0       0
# ...              ...              ...             ...     ...     ...
# 60168            5.0              9.0             3.0       1       1
# 60169            4.0              7.0             2.0       0       0
# 60170            2.0              0.0             4.0       1       1
# 60171            2.0              0.0             4.0       1       2
# 60172            4.0              7.0             2.0       0       2
#
# [60173 rows x 99 columns]

# %%
removed_columns = ['gameid', 'league', 'year', 'date', 'patch', 'teamname', 'result', 'target']
selected_columns = df.columns[~df.columns.isin(removed_columns)]
selected_columns
# Out:
# Index(['playoffs', 'side', 'gamelength', 'kills', 'deaths', 'assists',
#        'teamdeaths', 'doublekills', 'triplekills', 'quadrakills', 'pentakills',
#        'firstblood', 'team kpm', 'ckpm', 'firstdragon', 'dragons',
#        'opp_dragons', 'elementaldrakes', 'opp_elementaldrakes', 'infernals',
#        'mountains', 'clouds', 'oceans', 'chemtechs', 'hextechs', 'elders',
#        'opp_elders', 'firstherald', 'heralds', 'opp_heralds', 'firstbaron',
#        'barons', 'opp_barons', 'firsttower', 'towers', 'opp_towers',
#        'firstmidtower', 'firsttothreetowers', 'turretplates',
#        'opp_turretplates', 'inhibitors', 'opp_inhibitors', 'damagetochampions',
#        'dpm', 'damagetakenperminute', 'damagemitigatedperminute',
#        'wardsplaced', 'wpm', 'wardskilled', 'wcpm', 'controlwardsbought',
#        'visionscore', 'vspm', 'totalgold', 'earnedgold', 'earned gpm',
#        'goldspent', 'gspd', 'minionkills', 'monsterkills', 'cspm', 'goldat10',
#        'xpat10', 'csat10', 'opp_goldat10', 'opp_xpat10', 'opp_csat10',
#        'golddiffat10', 'xpdiffat10', 'csdiffat10', 'killsat10', 'assistsat10',
#        'deathsat10', 'opp_killsat10', 'opp_assistsat10', 'opp_deathsat10',
#        'goldat15', 'xpat15', 'csat15', 'opp_goldat15', 'opp_xpat15',
#        'opp_csat15', 'golddiffat15', 'xpdiffat15', 'csdiffat15', 'killsat15',
#        'assistsat15', 'deathsat15', 'opp_killsat15', 'opp_assistsat15',
#        'opp_deathsat15'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
df_rolling = df[list(selected_columns) + ['result', 'teamname', 'year']]
df_rolling
# Out:
#        playoffs  side  gamelength     kills    deaths   assists  teamdeaths  \
# 0           0.0   1.0    0.560360  0.283333  0.100000  0.350000    0.100000
# 1           0.0   0.0    0.560360  0.100000  0.283333  0.108333    0.283333
# 2           0.0   1.0    0.560466  0.283333  0.550000  0.341667    0.550000
# 3           0.0   0.0    0.560466  0.550000  0.300000  0.533333    0.300000
# 4           0.0   1.0    0.516311  0.216667  0.500000  0.125000    0.500000
# ...         ...   ...         ...       ...       ...       ...         ...
# 60168       0.0   1.0    0.000295  0.350000  0.283333  0.400000    0.283333
# 60169       0.0   0.0    0.000447  0.333333  0.416667  0.366667    0.416667
# 60170       0.0   1.0    0.000447  0.416667  0.333333  0.375000    0.333333
# 60171       0.0   1.0    0.000447  0.416667  0.333333  0.375000    0.333333
# 60172       0.0   0.0    0.000447  0.333333  0.416667  0.366667    0.416667
#
#        doublekills  triplekills  quadrakills  ...  csdiffat15  killsat15  \
# 0         0.272727     0.166667          0.0  ...    0.316742   0.142857
# 1         0.000000     0.000000          0.0  ...    0.683258   0.071429
# 2         0.181818     0.000000          0.0  ...    0.443439   0.142857
# 3         0.636364     0.333333          0.0  ...    0.556561   0.357143
# 4         0.000000     0.000000          0.0  ...    0.423077   0.178571
# ...            ...          ...          ...  ...         ...        ...
# 60168     0.272727     0.333333          0.0  ...    0.622172   0.107143
# 60169     0.181818     0.000000          0.0  ...    0.576923   0.071429
# 60170     0.454545     0.166667          0.0  ...    0.423077   0.142857
# 60171     0.454545     0.166667          0.0  ...    0.423077   0.142857
# 60172     0.181818     0.000000          0.0  ...    0.576923   0.071429
#
#        assistsat15  deathsat15  opp_killsat15  opp_assistsat15  \
# 0         0.063830    0.071429       0.071429         0.063830
# 1         0.063830    0.142857       0.142857         0.063830
# 2         0.106383    0.357143       0.357143         0.361702
# 3         0.361702    0.142857       0.142857         0.106383
# 4         0.085106    0.428571       0.428571         0.361702
# ...            ...         ...            ...              ...
# 60168     0.085106    0.178571       0.178571         0.191489
# 60169     0.000000    0.142857       0.142857         0.148936
# 60170     0.148936    0.071429       0.071429         0.000000
# 60171     0.148936    0.071429       0.071429         0.000000
# 60172     0.000000    0.142857       0.142857         0.148936
#
#        opp_deathsat15  result                     teamname  year
# 0            0.142857       1                   ConViction  2021
# 1            0.071429       0                  Mercenaries  2021
# 2            0.142857       0     Striking Vipers Maestros  2021
# 3            0.357143       1             RockTribeEsports  2021
# 4            0.178571       0  Purdue University Northwest  2021
# ...               ...     ...                          ...   ...
# 60168        0.107143       1                 Kawaii Kiwis  2024
# 60169        0.071429       0               Erfolg Esports  2024
# 60170        0.142857       1                 Kawaii Kiwis  2024
# 60171        0.142857       1                 Kawaii Kiwis  2024
# 60172        0.071429       0               Erfolg Esports  2024
#
# [60173 rows x 94 columns]

# %%
def find_rolling_average(team):
    rolling = team[list(selected_columns) + ['result']].rolling(10).mean()
    return rolling

df_rolling = df_rolling.groupby(['teamname', 'year'], group_keys=False).apply(find_rolling_average)
df_rolling
# Out:
#        playoffs  side  gamelength     kills    deaths   assists  teamdeaths  \
# 0           NaN   NaN         NaN       NaN       NaN       NaN         NaN
# 1           NaN   NaN         NaN       NaN       NaN       NaN         NaN
# 2           NaN   NaN         NaN       NaN       NaN       NaN         NaN
# 3           NaN   NaN         NaN       NaN       NaN       NaN         NaN
# 4           NaN   NaN         NaN       NaN       NaN       NaN         NaN
# ...         ...   ...         ...       ...       ...       ...         ...
# 60168       0.0   0.4    0.000283  0.313333  0.200000  0.343333    0.200000
# 60169       0.0   0.4    0.000354  0.258333  0.291667  0.295000    0.291667
# 60170       0.0   0.5    0.000291  0.311667  0.193333  0.332500    0.193333
# 60171       0.0   0.6    0.000300  0.310000  0.186667  0.321667    0.186667
# 60172       0.0   0.4    0.000350  0.236667  0.296667  0.261667    0.296667
#
#        doublekills  triplekills  quadrakills  ...  golddiffat15  xpdiffat15  \
# 0              NaN          NaN          NaN  ...           NaN         NaN
# 1              NaN          NaN          NaN  ...           NaN         NaN
# 2              NaN          NaN          NaN  ...           NaN         NaN
# 3              NaN          NaN          NaN  ...           NaN         NaN
# 4              NaN          NaN          NaN  ...           NaN         NaN
# ...            ...          ...          ...  ...           ...         ...
# 60168     0.254545          0.2     0.066667  ...      0.527467    0.583611
# 60169     0.172727          0.0     0.000000  ...      0.492539    0.498814
# 60170     0.272727          0.2     0.066667  ...      0.511957    0.564306
# 60171     0.290909          0.2     0.066667  ...      0.496447    0.545001
# 60172     0.163636          0.0     0.000000  ...      0.492768    0.505156
#
#        csdiffat15  killsat15  assistsat15  deathsat15  opp_killsat15  \
# 0             NaN        NaN          NaN         NaN            NaN
# 1             NaN        NaN          NaN         NaN            NaN
# 2             NaN        NaN          NaN         NaN            NaN
# 3             NaN        NaN          NaN         NaN            NaN
# 4             NaN        NaN          NaN         NaN            NaN
# ...           ...        ...          ...         ...            ...
# 60168    0.594570   0.185714     0.174468    0.100000       0.092857
# 60169    0.492308   0.110714     0.119149    0.110714       0.110714
# 60170    0.575566   0.164286     0.148936    0.096429       0.089286
# 60171    0.556561   0.142857     0.123404    0.092857       0.085714
# 60172    0.493665   0.107143     0.102128    0.107143       0.107143
#
#        opp_assistsat15  opp_deathsat15  result
# 0                  NaN             NaN     NaN
# 1                  NaN             NaN     NaN
# 2                  NaN             NaN     NaN
# 3                  NaN             NaN     NaN
# 4                  NaN             NaN     NaN
# ...                ...             ...     ...
# 60168         0.110638        0.185714     0.8
# 60169         0.106383        0.110714     0.5
# 60170         0.095745        0.164286     0.9
# 60171         0.080851        0.142857     1.0
# 60172         0.097872        0.107143     0.4
#
# [60173 rows x 92 columns]

# %%
rolling_cols = [f"{col}_last10" for col in df_rolling.columns]
df_rolling.columns = rolling_cols

df = pd.concat([df, df_rolling], axis=1)

# %%
df = df.dropna()

# %%
df
# Out:
#                       gameid league  year  playoffs                 date  \
# 81            NA1_3981119699    UPL  2021       0.0  2021-07-21 02:12:58
# 97            NA1_3986592690    UPL  2021       0.0  2021-07-24 01:08:24
# 103           NA1_3991807969    UPL  2021       0.0  2021-07-30 00:26:34
# 104           NA1_3991968137    UPL  2021       0.0  2021-07-30 01:41:31
# 105           NA1_3994701569    UPL  2021       0.0  2021-07-31 00:14:14
# ...                      ...    ...   ...       ...                  ...
# 60168  ESPORTSTMNT01_3436660   NEXO  2024       0.0  2023-11-20 19:05:47
# 60169  ESPORTSTMNT01_3438678   NEXO  2024       0.0  2023-11-20 19:59:21
# 60170  ESPORTSTMNT01_3438678   NEXO  2024       0.0  2023-11-20 19:59:21
# 60171  ESPORTSTMNT01_3438678   NEXO  2024       0.0  2023-11-20 19:59:21
# 60172  ESPORTSTMNT01_3438678   NEXO  2024       0.0  2023-11-20 19:59:21
#
#        patch  side                   teamname  gamelength     kills  ...  \
# 81     11.14   1.0                Mercenaries    0.544492  0.483333  ...
# 97     11.15   1.0  Striking Vipers Champions    0.722389  0.333333  ...
# 103    11.15   1.0  Striking Vipers Champions    0.727047  0.283333  ...
# 104    11.15   1.0  Striking Vipers Champions    0.531818  0.383333  ...
# 105    11.15   0.0                 ConViction    0.372147  0.050000  ...
# ...      ...   ...                        ...         ...       ...  ...
# 60168  13.22   1.0               Kawaii Kiwis    0.000295  0.350000  ...
# 60169  13.22   0.0             Erfolg Esports    0.000447  0.333333  ...
# 60170  13.22   1.0               Kawaii Kiwis    0.000447  0.416667  ...
# 60171  13.22   1.0               Kawaii Kiwis    0.000447  0.416667  ...
# 60172  13.22   0.0             Erfolg Esports    0.000447  0.333333  ...
#
#        golddiffat15_last10  xpdiffat15_last10  csdiffat15_last10  \
# 81                0.493896           0.506950           0.558145
# 97                0.540500           0.571648           0.574434
# 103               0.541823           0.572471           0.574208
# 104               0.545602           0.574711           0.588009
# 105               0.399007           0.456009           0.414253
# ...                    ...                ...                ...
# 60168             0.527467           0.583611           0.594570
# 60169             0.492539           0.498814           0.492308
# 60170             0.511957           0.564306           0.575566
# 60171             0.496447           0.545001           0.556561
# 60172             0.492768           0.505156           0.493665
#
#        killsat15_last10  assistsat15_last10  deathsat15_last10  \
# 81             0.210714            0.178723           0.207143
# 97             0.225000            0.195745           0.164286
# 103            0.214286            0.182979           0.157143
# 104            0.210714            0.180851           0.171429
# 105            0.185714            0.151064           0.260714
# ...                 ...                 ...                ...
# 60168          0.185714            0.174468           0.100000
# 60169          0.110714            0.119149           0.110714
# 60170          0.164286            0.148936           0.096429
# 60171          0.142857            0.123404           0.092857
# 60172          0.107143            0.102128           0.107143
#
#        opp_killsat15_last10  opp_assistsat15_last10  opp_deathsat15_last10  \
# 81                 0.207143                0.185106               0.210714
# 97                 0.164286                0.146809               0.225000
# 103                0.157143                0.144681               0.214286
# 104                0.171429                0.159574               0.210714
# 105                0.260714                0.204255               0.185714
# ...                     ...                     ...                    ...
# 60168              0.092857                0.110638               0.185714
# 60169              0.110714                0.106383               0.110714
# 60170              0.089286                0.095745               0.164286
# 60171              0.085714                0.080851               0.142857
# 60172              0.107143                0.097872               0.107143
#
#        result_last10
# 81               0.4
# 97               0.8
# 103              0.9
# 104              0.9
# 105              0.3
# ...              ...
# 60168            0.8
# 60169            0.5
# 60170            0.9
# 60171            1.0
# 60172            0.4
#
# [49256 rows x 191 columns]

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import RidgeClassifier

rr = RidgeClassifier(alpha=1)
split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr, n_features_to_select=25, direction='forward', cv=split)

# %%
df
# Out:
#                       gameid league  year  playoffs                 date  \
# 81            NA1_3981119699    UPL  2021       0.0  2021-07-21 02:12:58
# 97            NA1_3986592690    UPL  2021       0.0  2021-07-24 01:08:24
# 103           NA1_3991807969    UPL  2021       0.0  2021-07-30 00:26:34
# 104           NA1_3991968137    UPL  2021       0.0  2021-07-30 01:41:31
# 105           NA1_3994701569    UPL  2021       0.0  2021-07-31 00:14:14
# ...                      ...    ...   ...       ...                  ...
# 60168  ESPORTSTMNT01_3436660   NEXO  2024       0.0  2023-11-20 19:05:47
# 60169  ESPORTSTMNT01_3438678   NEXO  2024       0.0  2023-11-20 19:59:21
# 60170  ESPORTSTMNT01_3438678   NEXO  2024       0.0  2023-11-20 19:59:21
# 60171  ESPORTSTMNT01_3438678   NEXO  2024       0.0  2023-11-20 19:59:21
# 60172  ESPORTSTMNT01_3438678   NEXO  2024       0.0  2023-11-20 19:59:21
#
#        patch  side                   teamname  gamelength     kills  ...  \
# 81     11.14   1.0                Mercenaries    0.544492  0.483333  ...
# 97     11.15   1.0  Striking Vipers Champions    0.722389  0.333333  ...
# 103    11.15   1.0  Striking Vipers Champions    0.727047  0.283333  ...
# 104    11.15   1.0  Striking Vipers Champions    0.531818  0.383333  ...
# 105    11.15   0.0                 ConViction    0.372147  0.050000  ...
# ...      ...   ...                        ...         ...       ...  ...
# 60168  13.22   1.0               Kawaii Kiwis    0.000295  0.350000  ...
# 60169  13.22   0.0             Erfolg Esports    0.000447  0.333333  ...
# 60170  13.22   1.0               Kawaii Kiwis    0.000447  0.416667  ...
# 60171  13.22   1.0               Kawaii Kiwis    0.000447  0.416667  ...
# 60172  13.22   0.0             Erfolg Esports    0.000447  0.333333  ...
#
#        golddiffat15_last10  xpdiffat15_last10  csdiffat15_last10  \
# 81                0.493896           0.506950           0.558145
# 97                0.540500           0.571648           0.574434
# 103               0.541823           0.572471           0.574208
# 104               0.545602           0.574711           0.588009
# 105               0.399007           0.456009           0.414253
# ...                    ...                ...                ...
# 60168             0.527467           0.583611           0.594570
# 60169             0.492539           0.498814           0.492308
# 60170             0.511957           0.564306           0.575566
# 60171             0.496447           0.545001           0.556561
# 60172             0.492768           0.505156           0.493665
#
#        killsat15_last10  assistsat15_last10  deathsat15_last10  \
# 81             0.210714            0.178723           0.207143
# 97             0.225000            0.195745           0.164286
# 103            0.214286            0.182979           0.157143
# 104            0.210714            0.180851           0.171429
# 105            0.185714            0.151064           0.260714
# ...                 ...                 ...                ...
# 60168          0.185714            0.174468           0.100000
# 60169          0.110714            0.119149           0.110714
# 60170          0.164286            0.148936           0.096429
# 60171          0.142857            0.123404           0.092857
# 60172          0.107143            0.102128           0.107143
#
#        opp_killsat15_last10  opp_assistsat15_last10  opp_deathsat15_last10  \
# 81                 0.207143                0.185106               0.210714
# 97                 0.164286                0.146809               0.225000
# 103                0.157143                0.144681               0.214286
# 104                0.171429                0.159574               0.210714
# 105                0.260714                0.204255               0.185714
# ...                     ...                     ...                    ...
# 60168              0.092857                0.110638               0.185714
# 60169              0.110714                0.106383               0.110714
# 60170              0.089286                0.095745               0.164286
# 60171              0.085714                0.080851               0.142857
# 60172              0.107143                0.097872               0.107143
#
#        result_last10
# 81               0.4
# 97               0.8
# 103              0.9
# 104              0.9
# 105              0.3
# ...              ...
# 60168            0.8
# 60169            0.5
# 60170            0.9
# 60171            1.0
# 60172            0.4
#
# [49256 rows x 191 columns]

# %%
#use if considering rolling data
selected_cols2 = df.columns[~df.columns.isin(removed_columns)]
selected_cols2
# Out:
# Index(['playoffs', 'side', 'gamelength', 'kills', 'deaths', 'assists',
#        'teamdeaths', 'doublekills', 'triplekills', 'quadrakills',
#        ...
#        'golddiffat15_last10', 'xpdiffat15_last10', 'csdiffat15_last10',
#        'killsat15_last10', 'assistsat15_last10', 'deathsat15_last10',
#        'opp_killsat15_last10', 'opp_assistsat15_last10',
#        'opp_deathsat15_last10', 'result_last10'],
#       dtype='object', length=183)

# %%
sfs.fit(df[selected_columns], df['target'])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=25)

# %%
predictors = list(selected_columns[sfs.get_support()])
predictors
# Out:
# ['playoffs',
#  'side',
#  'firstblood',
#  'oceans',
#  'opp_elders',
#  'firstbaron',
#  'towers',
#  'opp_towers',
#  'damagetakenperminute',
#  'damagemitigatedperminute',
#  'wardsplaced',
#  'wpm',
#  'earned gpm',
#  'goldspent',
#  'minionkills',
#  'opp_xpat10',
#  'killsat10',
#  'deathsat10',
#  'opp_killsat10',
#  'opp_deathsat10',
#  'killsat15',
#  'deathsat15',
#  'opp_killsat15',
#  'opp_assistsat15',
#  'opp_deathsat15']

# %%
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []

    seasons = sorted(data['year'].unique())
    for i in range(start, len(seasons), step):
        current = seasons[i]
        train = data[data['year'] < current]
        test = data[data['year'] == current]

        model.fit(train[predictors], train['target'])
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test['target'], preds], axis=1)

        combined.columns = ['actual', 'predictions']

        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)
predictiontest = predictions[predictions["actual"] != 2]
predictions
# Out:
#        actual  predictions
# 21550       1            1
# 21638       2            1
# 21648       0            0
# 21655       0            1
# 21659       1            1
# ...       ...          ...
# 60168       1            1
# 60169       0            1
# 60170       1            0
# 60171       2            0
# 60172       2            1
#
# [32260 rows x 2 columns]

# %%
df.groupby('firstblood').apply(lambda x: x[x['result'] == 1].shape[0] / x.shape[0])
# Out:
# firstblood
# 0.0    0.394781
# 1.0    0.609944
# dtype: float64

# %%
from sklearn.metrics import accuracy_score

accuracy_score(predictions['actual'], predictions['predictions'])
# Out:
# 0.7552386856788593

# %%
# without rows where actual is 2 (i.e. no next game to predict)
accuracy_score(predictiontest['actual'], predictiontest['predictions'])
# Out:
# 0.7658263657509272
