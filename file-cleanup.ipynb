# %%
import pandas as pd

# %%
years = [i for i in range(2019, 2024)]

# %%
def clean_file(orig_dir, year):
    path = f"{orig_dir}/{year}_LoL_esports_match_data_from_OraclesElixir.csv"
    df = pd.read_csv(path, index_col=0)
    df = df[df['datacompleteness'].str.contains('complete')]
    df = df[df['position'].str.contains('team')]
    del df['datacompleteness']
    del df['participantid']
    del df['teamid']
    del df['position']
    del df['teamkills']
    df = df.dropna(subset=['teamname', 'damagetochampions', 'dragons', 'goldat15', 'minionkills', 'visionscore', 'heralds'])
    df = df[~df['teamname'].str.contains('unknown team')]
    for s in ['quadrakills', 'pentakills', 'chemtechs', 'hextechs', 'elders', 'opp_elders', 'firstmidtower', 'firstbaron', 'inhibitors', 'opp_inhibitors']:
        df[s][pd.isnull(df[s])] = 0
    df = df.sort_values('date')
    df = df.reset_index()
    return df

# %%
# df19 = clean_file('data', 2019)
# df20 = clean_file("data", 2020)
# df21 = clean_file("data", 2021)
# df22 = clean_file("data", 2022)
df = clean_file("data", 2023)
years.reverse()
for year in years:
    df_temp = clean_file("data", year)
    df = pd.concat([df_temp, df], ignore_index=True)
# Out:
# /var/folders/_6/_dxmrgx91s127f4vpswlc2700000gn/T/ipykernel_33875/398860759.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, index_col=0)
# /var/folders/_6/_dxmrgx91s127f4vpswlc2700000gn/T/ipykernel_33875/398860759.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, index_col=0)
# /var/folders/_6/_dxmrgx91s127f4vpswlc2700000gn/T/ipykernel_33875/398860759.py:3: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, index_col=0)

# %%
# df = pd.concat([df19, df20, df21, df22, df23], ignore_index=True)
df = df.sort_values('date').reset_index(drop=True)
df
# Out:
#                       gameid  \
# 0      ESPORTSTMNT01/1030526
# 1      ESPORTSTMNT01/1030526
# 2      ESPORTSTMNT01/1040501
# 3      ESPORTSTMNT01/1040501
# 4      ESPORTSTMNT01/1040511
# ...                      ...
# 97851  ESPORTSTMNT01_3436660
# 97852  ESPORTSTMNT01_3438678
# 97853  ESPORTSTMNT01_3438678
# 97854  ESPORTSTMNT01_3438678
# 97855  ESPORTSTMNT01_3438678
#
#                                                      url league  year  \
# 0      https://matchhistory.br.leagueoflegends.com/pt...  CBLOL  2019
# 1      https://matchhistory.br.leagueoflegends.com/pt...  CBLOL  2019
# 2      https://matchhistory.br.leagueoflegends.com/pt...  CBLOL  2019
# 3      https://matchhistory.br.leagueoflegends.com/pt...  CBLOL  2019
# 4      https://matchhistory.br.leagueoflegends.com/pt...  CBLOL  2019
# ...                                                  ...    ...   ...
# 97851                                                NaN   NEXO  2024
# 97852                                                NaN   NEXO  2024
# 97853                                                NaN   NEXO  2024
# 97854                                                NaN   NEXO  2024
# 97855                                                NaN   NEXO  2024
#
#          split  playoffs                 date  game  patch  side  ...  \
# 0      Split 1         0  2019-01-12 14:56:22   1.0   9.01  Blue  ...
# 1      Split 1         0  2019-01-12 14:56:22   1.0   9.01   Red  ...
# 2      Split 1         0  2019-01-12 16:06:12   1.0   9.01  Blue  ...
# 3      Split 1         0  2019-01-12 16:06:12   1.0   9.01   Red  ...
# 4      Split 1         0  2019-01-12 17:17:33   1.0   9.01  Blue  ...
# ...        ...       ...                  ...   ...    ...   ...  ...
# 97851  Split 1         0  2023-11-20 19:05:47   1.0  13.22  Blue  ...
# 97852  Split 1         0  2023-11-20 19:59:21   2.0  13.22  Blue  ...
# 97853  Split 1         0  2023-11-20 19:59:21   2.0  13.22  Blue  ...
# 97854  Split 1         0  2023-11-20 19:59:21   2.0  13.22   Red  ...
# 97855  Split 1         0  2023-11-20 19:59:21   2.0  13.22   Red  ...
#
#       opp_csat15 golddiffat15 xpdiffat15 csdiffat15 killsat15 assistsat15  \
# 0          468.0       2579.0     1391.0       22.0       7.0        15.0
# 1          490.0      -2579.0    -1391.0      -22.0       4.0         2.0
# 2          531.0       1467.0    -1261.0      -47.0       5.0         6.0
# 3          484.0      -1467.0     1261.0       47.0       1.0         2.0
# 4          548.0      -1586.0     -928.0      -25.0       0.0         0.0
# ...          ...          ...        ...        ...       ...         ...
# 97851      461.0        -75.0      545.0       54.0       3.0         4.0
# 97852      515.0       -660.0    -1568.0      -34.0       4.0         7.0
# 97853      515.0       -660.0    -1568.0      -34.0       4.0         7.0
# 97854      481.0        660.0     1568.0       34.0       2.0         0.0
# 97855      481.0        660.0     1568.0       34.0       2.0         0.0
#
#       deathsat15 opp_killsat15 opp_assistsat15  opp_deathsat15
# 0            4.0           4.0             2.0             7.0
# 1            7.0           7.0            15.0             4.0
# 2            1.0           1.0             2.0             5.0
# 3            5.0           5.0             6.0             1.0
# 4            0.0           0.0             0.0             0.0
# ...          ...           ...             ...             ...
# 97851        5.0           5.0             9.0             3.0
# 97852        2.0           2.0             0.0             4.0
# 97853        2.0           2.0             0.0             4.0
# 97854        4.0           4.0             7.0             2.0
# 97855        4.0           4.0             7.0             2.0
#
# [97856 rows x 118 columns]

# %%
nulls = pd.isnull(df)
nulls = nulls.sum()
nulls = nulls[nulls > 0]
nulls
# Out:
# url                        57624
# split                      25252
# game                          80
# playername                 97856
# playerid                   97856
# champion                   97856
# ban1                         415
# ban2                         222
# ban3                         447
# ban4                         299
# ban5                         520
# firstbloodkill             97856
# firstbloodassist           97856
# firstbloodvictim           97856
# firstdragon                    6
# elementaldrakes            37683
# opp_elementaldrakes        37683
# dragons (type unknown)     97197
# turretplates               37683
# opp_turretplates           37683
# damageshare                97856
# earnedgoldshare            97856
# total cs                   97856
# monsterkillsownjungle      60173
# monsterkillsenemyjungle    60173
# dtype: int64

# %%
valid_columns = df.columns[~df.columns.isin(nulls.index)]
valid_columns
# Out:
# Index(['gameid', 'league', 'year', 'playoffs', 'date', 'patch', 'side',
#        'teamname', 'gamelength', 'result', 'kills', 'deaths', 'assists',
#        'teamdeaths', 'doublekills', 'triplekills', 'quadrakills', 'pentakills',
#        'firstblood', 'team kpm', 'ckpm', 'dragons', 'opp_dragons', 'infernals',
#        'mountains', 'clouds', 'oceans', 'chemtechs', 'hextechs', 'elders',
#        'opp_elders', 'firstherald', 'heralds', 'opp_heralds', 'firstbaron',
#        'barons', 'opp_barons', 'firsttower', 'towers', 'opp_towers',
#        'firstmidtower', 'firsttothreetowers', 'inhibitors', 'opp_inhibitors',
#        'damagetochampions', 'dpm', 'damagetakenperminute',
#        'damagemitigatedperminute', 'wardsplaced', 'wpm', 'wardskilled', 'wcpm',
#        'controlwardsbought', 'visionscore', 'vspm', 'totalgold', 'earnedgold',
#        'earned gpm', 'goldspent', 'gspd', 'minionkills', 'monsterkills',
#        'cspm', 'goldat10', 'xpat10', 'csat10', 'opp_goldat10', 'opp_xpat10',
#        'opp_csat10', 'golddiffat10', 'xpdiffat10', 'csdiffat10', 'killsat10',
#        'assistsat10', 'deathsat10', 'opp_killsat10', 'opp_assistsat10',
#        'opp_deathsat10', 'goldat15', 'xpat15', 'csat15', 'opp_goldat15',
#        'opp_xpat15', 'opp_csat15', 'golddiffat15', 'xpdiffat15', 'csdiffat15',
#        'killsat15', 'assistsat15', 'deathsat15', 'opp_killsat15',
#        'opp_assistsat15', 'opp_deathsat15'],
#       dtype='object')

# %%
df = df[valid_columns].copy()
df
# Out:
#                       gameid league  year  playoffs                 date  \
# 0      ESPORTSTMNT01/1030526  CBLOL  2019         0  2019-01-12 14:56:22
# 1      ESPORTSTMNT01/1030526  CBLOL  2019         0  2019-01-12 14:56:22
# 2      ESPORTSTMNT01/1040501  CBLOL  2019         0  2019-01-12 16:06:12
# 3      ESPORTSTMNT01/1040501  CBLOL  2019         0  2019-01-12 16:06:12
# 4      ESPORTSTMNT01/1040511  CBLOL  2019         0  2019-01-12 17:17:33
# ...                      ...    ...   ...       ...                  ...
# 97851  ESPORTSTMNT01_3436660   NEXO  2024         0  2023-11-20 19:05:47
# 97852  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
# 97853  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
# 97854  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
# 97855  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
#
#        patch  side           teamname  gamelength  result  ...  opp_csat15  \
# 0       9.01  Blue   Flamengo Esports        1770       1  ...       468.0
# 1       9.01   Red    KaBuM! e-Sports        1770       0  ...       490.0
# 2       9.01  Blue          Vivo Keyd        2362       0  ...       531.0
# 3       9.01   Red   Uppercut esports        2362       1  ...       484.0
# 4       9.01  Blue  ProGaming Esports        2128       0  ...       548.0
# ...      ...   ...                ...         ...     ...  ...         ...
# 97851  13.22  Blue       Kawaii Kiwis        1940       1  ...       461.0
# 97852  13.22  Blue       Kawaii Kiwis        2464       1  ...       515.0
# 97853  13.22  Blue       Kawaii Kiwis        2464       1  ...       515.0
# 97854  13.22   Red     Erfolg Esports        2464       0  ...       481.0
# 97855  13.22   Red     Erfolg Esports        2464       0  ...       481.0
#
#        golddiffat15  xpdiffat15  csdiffat15  killsat15  assistsat15  \
# 0            2579.0      1391.0        22.0        7.0         15.0
# 1           -2579.0     -1391.0       -22.0        4.0          2.0
# 2            1467.0     -1261.0       -47.0        5.0          6.0
# 3           -1467.0      1261.0        47.0        1.0          2.0
# 4           -1586.0      -928.0       -25.0        0.0          0.0
# ...             ...         ...         ...        ...          ...
# 97851         -75.0       545.0        54.0        3.0          4.0
# 97852        -660.0     -1568.0       -34.0        4.0          7.0
# 97853        -660.0     -1568.0       -34.0        4.0          7.0
# 97854         660.0      1568.0        34.0        2.0          0.0
# 97855         660.0      1568.0        34.0        2.0          0.0
#
#        deathsat15  opp_killsat15  opp_assistsat15  opp_deathsat15
# 0             4.0            4.0              2.0             7.0
# 1             7.0            7.0             15.0             4.0
# 2             1.0            1.0              2.0             5.0
# 3             5.0            5.0              6.0             1.0
# 4             0.0            0.0              0.0             0.0
# ...           ...            ...              ...             ...
# 97851         5.0            5.0              9.0             3.0
# 97852         2.0            2.0              0.0             4.0
# 97853         2.0            2.0              0.0             4.0
# 97854         4.0            4.0              7.0             2.0
# 97855         4.0            4.0              7.0             2.0
#
# [97856 rows x 93 columns]

# %%
result = df.pop('result')
df.insert(len(df.columns), 'result', result)

# %%
def add_target(team):
    team['target'] = team['result'].shift(-1)
    return team

df = df.groupby('teamname', group_keys=False).apply(add_target)

# %%
df[df['teamname'] == 'T1']
# Out:
#                       gameid league  year  playoffs                 date  \
# 12167  ESPORTSTMNT03/1241159  KeSPA  2020         0  2019-12-31 07:48:28
# 12170  ESPORTSTMNT03/1241170  KeSPA  2020         0  2019-12-31 08:53:42
# 12172  ESPORTSTMNT03/1241176  KeSPA  2020         0  2019-12-31 09:49:08
# 12178  ESPORTSTMNT03/1241318  KeSPA  2020         0  2020-01-03 07:33:26
# 12180  ESPORTSTMNT03/1241322  KeSPA  2020         0  2020-01-03 09:00:58
# ...                      ...    ...   ...       ...                  ...
# 97826  ESPORTSTMNT03_3228396   WLDs  2023         0  2023-11-19 08:56:48
# 97828  ESPORTSTMNT03_3227846   WLDs  2023         0  2023-11-19 09:51:16
# 97831  ESPORTSTMNT03_3227846   WLDs  2023         0  2023-11-19 09:51:16
# 97832  ESPORTSTMNT03_3227847   WLDs  2023         0  2023-11-19 10:44:06
# 97834  ESPORTSTMNT03_3227847   WLDs  2023         0  2023-11-19 10:44:06
#
#        patch  side teamname  gamelength  kills  ...  xpdiffat15  csdiffat15  \
# 12167   9.24   Red       T1        2149     17  ...      1352.0        30.0
# 12170   9.24   Red       T1        2062      7  ...      -910.0        25.0
# 12172   9.24   Red       T1        2837     17  ...      -714.0       -34.0
# 12178   9.24   Red       T1        2220     11  ...      1665.0        12.0
# 12180   9.24  Blue       T1        2227      5  ...     -4833.0       -56.0
# ...      ...   ...      ...         ...    ...  ...         ...         ...
# 97826  13.19   Red       T1        1831     14  ...      -208.0        58.0
# 97828  13.19   Red       T1        1797     14  ...       913.0        43.0
# 97831  13.19   Red       T1        1797     14  ...       913.0        43.0
# 97832  13.19   Red       T1        1547     19  ...      1357.0        25.0
# 97834  13.19   Red       T1        1547     19  ...      1357.0        25.0
#
#        killsat15  assistsat15  deathsat15  opp_killsat15  opp_assistsat15  \
# 12167        3.0          3.0         3.0            3.0              8.0
# 12170        1.0          2.0         5.0            5.0             14.0
# 12172        2.0          5.0         1.0            1.0              2.0
# 12178        1.0          2.0         0.0            0.0              0.0
# 12180        0.0          0.0         6.0            6.0              7.0
# ...          ...          ...         ...            ...              ...
# 97826        2.0          5.0         4.0            4.0              6.0
# 97828        2.0          3.0         1.0            0.0              0.0
# 97831        2.0          3.0         1.0            0.0              0.0
# 97832        3.0          7.0         3.0            3.0              6.0
# 97834        3.0          7.0         3.0            3.0              6.0
#
#        opp_deathsat15  result  target
# 12167             3.0       1     0.0
# 12170             1.0       0     1.0
# 12172             2.0       1     0.0
# 12178             1.0       0     0.0
# 12180             0.0       0     1.0
# ...               ...     ...     ...
# 97826             3.0       1     1.0
# 97828             2.0       1     1.0
# 97831             2.0       1     1.0
# 97832             3.0       1     1.0
# 97834             3.0       1     NaN
#
# [649 rows x 94 columns]

# %%
df['target'][pd.isnull(df['target'])] = 2
df['target'] = df['target'].astype(int, errors='ignore')
df
# Out:
# /var/folders/_6/_dxmrgx91s127f4vpswlc2700000gn/T/ipykernel_33875/3500486044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['target'][pd.isnull(df['target'])] = 2
#                       gameid league  year  playoffs                 date  \
# 0      ESPORTSTMNT01/1030526  CBLOL  2019         0  2019-01-12 14:56:22
# 1      ESPORTSTMNT01/1030526  CBLOL  2019         0  2019-01-12 14:56:22
# 2      ESPORTSTMNT01/1040501  CBLOL  2019         0  2019-01-12 16:06:12
# 3      ESPORTSTMNT01/1040501  CBLOL  2019         0  2019-01-12 16:06:12
# 4      ESPORTSTMNT01/1040511  CBLOL  2019         0  2019-01-12 17:17:33
# ...                      ...    ...   ...       ...                  ...
# 97851  ESPORTSTMNT01_3436660   NEXO  2024         0  2023-11-20 19:05:47
# 97852  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
# 97853  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
# 97854  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
# 97855  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
#
#        patch  side           teamname  gamelength  kills  ...  xpdiffat15  \
# 0       9.01  Blue   Flamengo Esports        1770     17  ...      1391.0
# 1       9.01   Red    KaBuM! e-Sports        1770      9  ...     -1391.0
# 2       9.01  Blue          Vivo Keyd        2362     16  ...     -1261.0
# 3       9.01   Red   Uppercut esports        2362     12  ...      1261.0
# 4       9.01  Blue  ProGaming Esports        2128      2  ...      -928.0
# ...      ...   ...                ...         ...    ...  ...         ...
# 97851  13.22  Blue       Kawaii Kiwis        1940     21  ...       545.0
# 97852  13.22  Blue       Kawaii Kiwis        2464     25  ...     -1568.0
# 97853  13.22  Blue       Kawaii Kiwis        2464     25  ...     -1568.0
# 97854  13.22   Red     Erfolg Esports        2464     20  ...      1568.0
# 97855  13.22   Red     Erfolg Esports        2464     20  ...      1568.0
#
#        csdiffat15  killsat15  assistsat15  deathsat15  opp_killsat15  \
# 0            22.0        7.0         15.0         4.0            4.0
# 1           -22.0        4.0          2.0         7.0            7.0
# 2           -47.0        5.0          6.0         1.0            1.0
# 3            47.0        1.0          2.0         5.0            5.0
# 4           -25.0        0.0          0.0         0.0            0.0
# ...           ...        ...          ...         ...            ...
# 97851        54.0        3.0          4.0         5.0            5.0
# 97852       -34.0        4.0          7.0         2.0            2.0
# 97853       -34.0        4.0          7.0         2.0            2.0
# 97854        34.0        2.0          0.0         4.0            4.0
# 97855        34.0        2.0          0.0         4.0            4.0
#
#        opp_assistsat15  opp_deathsat15  result  target
# 0                  2.0             7.0       1       1
# 1                 15.0             4.0       0       0
# 2                  2.0             5.0       0       0
# 3                  6.0             1.0       1       1
# 4                  0.0             0.0       0       0
# ...                ...             ...     ...     ...
# 97851              9.0             3.0       1       1
# 97852              0.0             4.0       1       1
# 97853              0.0             4.0       1       2
# 97854              7.0             2.0       0       0
# 97855              7.0             2.0       0       2
#
# [97856 rows x 94 columns]

# %%
df['side'].replace({'Blue': 1}, inplace=True)
df['side'].replace({'Red': 0}, inplace=True)
df
# Out:
#                       gameid league  year  playoffs                 date  \
# 0      ESPORTSTMNT01/1030526  CBLOL  2019         0  2019-01-12 14:56:22
# 1      ESPORTSTMNT01/1030526  CBLOL  2019         0  2019-01-12 14:56:22
# 2      ESPORTSTMNT01/1040501  CBLOL  2019         0  2019-01-12 16:06:12
# 3      ESPORTSTMNT01/1040501  CBLOL  2019         0  2019-01-12 16:06:12
# 4      ESPORTSTMNT01/1040511  CBLOL  2019         0  2019-01-12 17:17:33
# ...                      ...    ...   ...       ...                  ...
# 97851  ESPORTSTMNT01_3436660   NEXO  2024         0  2023-11-20 19:05:47
# 97852  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
# 97853  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
# 97854  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
# 97855  ESPORTSTMNT01_3438678   NEXO  2024         0  2023-11-20 19:59:21
#
#        patch  side           teamname  gamelength  kills  ...  xpdiffat15  \
# 0       9.01     1   Flamengo Esports        1770     17  ...      1391.0
# 1       9.01     0    KaBuM! e-Sports        1770      9  ...     -1391.0
# 2       9.01     1          Vivo Keyd        2362     16  ...     -1261.0
# 3       9.01     0   Uppercut esports        2362     12  ...      1261.0
# 4       9.01     1  ProGaming Esports        2128      2  ...      -928.0
# ...      ...   ...                ...         ...    ...  ...         ...
# 97851  13.22     1       Kawaii Kiwis        1940     21  ...       545.0
# 97852  13.22     1       Kawaii Kiwis        2464     25  ...     -1568.0
# 97853  13.22     1       Kawaii Kiwis        2464     25  ...     -1568.0
# 97854  13.22     0     Erfolg Esports        2464     20  ...      1568.0
# 97855  13.22     0     Erfolg Esports        2464     20  ...      1568.0
#
#        csdiffat15  killsat15  assistsat15  deathsat15  opp_killsat15  \
# 0            22.0        7.0         15.0         4.0            4.0
# 1           -22.0        4.0          2.0         7.0            7.0
# 2           -47.0        5.0          6.0         1.0            1.0
# 3            47.0        1.0          2.0         5.0            5.0
# 4           -25.0        0.0          0.0         0.0            0.0
# ...           ...        ...          ...         ...            ...
# 97851        54.0        3.0          4.0         5.0            5.0
# 97852       -34.0        4.0          7.0         2.0            2.0
# 97853       -34.0        4.0          7.0         2.0            2.0
# 97854        34.0        2.0          0.0         4.0            4.0
# 97855        34.0        2.0          0.0         4.0            4.0
#
#        opp_assistsat15  opp_deathsat15  result  target
# 0                  2.0             7.0       1       1
# 1                 15.0             4.0       0       0
# 2                  2.0             5.0       0       0
# 3                  6.0             1.0       1       1
# 4                  0.0             0.0       0       0
# ...                ...             ...     ...     ...
# 97851              9.0             3.0       1       1
# 97852              0.0             4.0       1       1
# 97853              0.0             4.0       1       2
# 97854              7.0             2.0       0       0
# 97855              7.0             2.0       0       2
#
# [97856 rows x 94 columns]

# %%
df.to_csv('cleaned_data.csv')
